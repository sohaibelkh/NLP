# %% [markdown]
# #  NLP Pipeline – Arabic PDF Processing
#
# This notebook:
# - Extracts text from a PDF
# - Cleans Arabic text
# - Tokenizes and removes stopwords
# - Converts text to TF-IDF

# %%
# !pip install PyPDF2 scikit-learn

# %%
import re
import PyPDF2
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            if page.extract_text():
                text += page.extract_text()
    return text

# %%
def clean_arabic_text(text):
    text = re.sub(r"[^؀-ۿ\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
def tokenize_arabic(text):
    return text.split()

# %%
arabic_stopwords = [
    "في","من","على","و","الى","عن","هذا","هذه","هو","هي","كما","أن","إن","كان","كانت"
]

def remove_stopwords(tokens):
    return [word for word in tokens if word not in arabic_stopwords]

# %%
pdf_path = "text.pdf"

# Step 1: Extract
raw_text = extract_text_from_pdf(pdf_path)

# Step 2: Clean
clean_text = clean_arabic_text(raw_text)

# Step 3: Tokenize
tokens = tokenize_arabic(clean_text)

# Step 4: Remove stopwords
tokens_filtered = remove_stopwords(tokens)

# Step 5: Join back
final_text = " ".join(tokens_filtered)

print("Sample tokens:", tokens_filtered[:20])
# Out:
# Sample tokens: ['مٍ', 'ّر', 'رٍ', 'ذھ،', 'أ', 'ان', 'طً', 'أر', 'ن', 'أي', 'وتٍ', 'ّف', 'اوّت', 'ارة', 'ف', 'واب', 'اة', 'دّم', 'اوو', 'م']

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([final_text])

print("TF-IDF shape:", X.shape)
print("Top words:", vectorizer.get_feature_names_out()[:10])
# Out:
# TF-IDF shape: (1, 94)
# Top words: ['أت' 'أد' 'أر' 'أرى' 'أل' 'أن' 'أوب' 'أي' 'أھ' 'أھدا']
